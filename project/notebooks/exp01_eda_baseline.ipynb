# %%
import pandas as pd
from pathlib import Path

DATA_DIR = Path.cwd().parent / "data"

books   = pd.read_csv(DATA_DIR / "books.csv")
ratings = pd.read_csv(DATA_DIR / "ratings.csv")

# %% [markdown]
# ### Наблюдения по загрузке
#
# - `books.csv` — метаданные 10 000 книг
# - `ratings.csv` — индивидуальные оценки пользователей (1–5), основа для коллаборативной фильтрации

# %%
print("=== books.csv ===")
print(f"Размер: {books.shape}")
print(f"Колонки: {books.columns.tolist()}")
print(books.head(3))

print("\n=== ratings.csv ===")
print(f"Размер: {ratings.shape}")
print(f"Колонки: {ratings.columns.tolist()}")
print(ratings.head(3))

# %% [markdown]
# print("Пропуски в books.csv:")
# print(books.isnull().sum()[books.isnull().sum() > 0])
#
# print("\nПропуски в ratings.csv:")
# print(ratings.isnull().sum()[ratings.isnull().sum() > 0] or "нет")

# %%
df.rename(columns=str.strip, inplace=True)

df.publication_date = pd.to_datetime(df.publication_date, errors='coerce')
